# %%
import cv2

# %%
img = cv2.imread(r"D:\Python\OpenCV\images\Screenshot 2024-12-23 114732.png")

img = cv2.resize(img,(500,500))
print(img.shape)

new_image = cv2.Canny(img,100,120)
print(new_image.shape)

cv2.imshow("Mavi", new_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (500, 500, 3)
# (500, 500)
