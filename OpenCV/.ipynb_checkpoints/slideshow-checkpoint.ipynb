# %%
import cv2
import numpy as np

# %%
img = cv2.imread("images/Screenshot 2024-12-22 180436.png")
#Resize of image
resize = cv2.resize(img,(400,500))
cv2.imshow("Founder of S8UL",resize)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Multiple image using numpy in opencv

v =
