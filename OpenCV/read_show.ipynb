# %%
import cv2

# %%
#Read and show Image

# %%
img = cv2.imread("images/Screenshot 2024-10-17 035715.png") #image read
cv2.imshow("asmetop", img) #image show
cv2.waitKey(3000)  # Wait until any key is pressed
cv2.destroyAllWindows() #closes all the windows
# cv2.destroyWindow("asmetop") #closes the particular window passed
